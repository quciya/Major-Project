# %% [markdown]
# <a href="https://colab.research.google.com/github/quciya/Major-Project/blob/main/final_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 2.x
! pip install h5py==2.10
# Out:
# Requirement already satisfied: h5py==2.10 in /usr/local/lib/python3.7/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.10) (1.21.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.10) (1.15.0)

# %%
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, UpSampling2D, Input,Reshape, concatenate
from tensorflow.keras.layers import Activation, Dense, Dropout, Flatten, InputLayer
from tensorflow.keras.layers import BatchNormalization, RepeatVector
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications import efficientnet
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import skimage
from skimage.color import rgb2lab, lab2rgb, rgb2gray, gray2rgb
from skimage.io import imsave
from skimage.transform import resize
import numpy as np
import os
import random
import tensorflow as tf
import matplotlib.pyplot as plt
import gc
from warnings import filterwarnings
filterwarnings("ignore")

# %%
"""!pip install split-folders"""
# Out:
# '!pip install split-folders'

# %%
""""import splitfolders
splitfolders.ratio('/content/drive/MyDrive/Major_Project/Image_Dataset/Sagun/', output="/content/drive/MyDrive/Major_Project/Image_Dataset/Sagun/", seed=1337, ratio=(.8, 0.1,0.1)) """"
# Out:
#   File "<ipython-input-5-6c46956403f5>", line 2
#     splitfolders.ratio('/content/drive/MyDrive/Major_Project/Image_Dataset/Sagun/', output="/content/drive/MyDrive/Major_Project/Image_Dataset/Sagun/", seed=1337, ratio=(.8, 0.1,0.1)) """"
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
embed_input = Input(shape=(1000,))

#Encoder
encoder_input = Input(shape=(256, 256, 1,))
encoder_output = Conv2D(64, (3,3), activation='relu', padding='same', strides=2)(encoder_input)
encoder_output = Conv2D(128, (3,3), activation='relu', padding='same')(encoder_output)
encoder_output = Conv2D(128, (3,3), activation='relu', padding='same', strides=2)(encoder_output)
encoder_output = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output)
encoder_output = Conv2D(256, (3,3), activation='relu', padding='same', strides=2)(encoder_output)
encoder_output = Conv2D(512, (3,3), activation='relu', padding='same')(encoder_output)
encoder_output = Conv2D(512, (3,3), activation='relu', padding='same')(encoder_output)
encoder_output = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output)

#Fusion
fusion_output = RepeatVector(32 * 32)(embed_input) 
fusion_output = Reshape(([32, 32, 1000]))(fusion_output)
fusion_output = concatenate([encoder_output, fusion_output], axis=3) 
fusion_output = Conv2D(256, (1, 1), activation='relu', padding='same')(fusion_output) 

#Decoder
decoder_output = Conv2D(128, (3,3), activation='relu', padding='same')(fusion_output)
decoder_output = UpSampling2D((2, 2))(decoder_output)
decoder_output = Conv2D(64, (3,3), activation='relu', padding='same')(decoder_output)
decoder_output = UpSampling2D((2, 2))(decoder_output)
decoder_output = Conv2D(32, (3,3), activation='relu', padding='same')(decoder_output)
decoder_output = Conv2D(16, (3,3), activation='relu', padding='same')(decoder_output)
decoder_output = Conv2D(2, (3, 3), activation='tanh', padding='same')(decoder_output)
decoder_output = UpSampling2D((2, 2))(decoder_output)

model = Model(inputs=[encoder_input, embed_input], outputs=decoder_output)

# %%
#Load weights
inception = tf.keras.applications.efficientnet.EfficientNetB0(
    include_top=True, weights='imagenet', input_tensor=None, classifier_activation="softmax",
)

# %%
#Create embedding
def create_inception_embedding(grayscaled_rgb):
    grayscaled_rgb_resized = []
    for i in grayscaled_rgb:
        i = resize(i, (299, 299, 3), mode='constant')
        grayscaled_rgb_resized.append(i)
    grayscaled_rgb_resized = np.array(grayscaled_rgb_resized)
    grayscaled_rgb_resized = preprocess_input(grayscaled_rgb_resized)
    embed = inception.predict(grayscaled_rgb_resized)
    return embed

# %%
class InceptionImageGenerator(tf.keras.utils.Sequence):
    def __init__(self, img_dir, img_size=(256,256),batch_size=16,shuffle=True):
        self.batch_size = batch_size
        self.img_dir = img_dir
        self.img_size = img_size
        self.img_list = os.listdir(self.img_dir)
        self.n = len(self.img_list)
        self.shuffle = shuffle
        self.on_epoch_end() 

    def __len__(self):
        '''Denotes the number of batches per epoch'''
        return int(np.ceil(self.n/self.batch_size))

    def __getitem__(self,index):
        indices = self.indices[index*self.batch_size:(index+1)*self.batch_size]

        batch_filenames = [self.img_list[i] for i in indices]

        X, embed, y = self.__get_data(batch_filenames)
        
        return ([X, embed], y)

    def __get_data(self, batch_filenames):
        
        imgs = []
        for i, fname in enumerate(batch_filenames):
            img = img_to_array(load_img(self.img_dir + fname,target_size=self.img_size))
            imgs.append(img)
        imgs = np.array(imgs)
        #apply on batch
        grayscaled_rgb = gray2rgb(rgb2gray(imgs))
        embed = self.create_inception_embedding(grayscaled_rgb)

        img_lab = rgb2lab(imgs/255.0)
        img_l = np.expand_dims(img_lab[:,:,:,0],-1) #(h,w,1)
        img_ab = img_lab[:,:,:,1:]/128    
        del imgs          
        
        return np.array(img_l),np.array(embed),np.array(img_ab)

    def on_epoch_end(self):
        self.indices = np.arange(self.n)
        if self.shuffle:
            np.random.shuffle(self.indices)

    def create_inception_embedding(self, grayscaled_rgb):

        grayscaled_rgb_resized = []
        for i in grayscaled_rgb:
            i = resize(i, (224, 224, 3), mode='constant')
            grayscaled_rgb_resized.append(i)
        grayscaled_rgb_resized = np.array(grayscaled_rgb_resized)
        grayscaled_rgb_resized = preprocess_input(grayscaled_rgb_resized)
        embed = inception.predict(grayscaled_rgb_resized)

        return embed

# %%
incep_train_datagen = InceptionImageGenerator('/content/drive/MyDrive/Major_Project/Image_Dataset/Sagun/train/colored/',batch_size=32,img_size=(256,256))
incep_test_datagen = InceptionImageGenerator('/content/drive/MyDrive/Major_Project/Image_Dataset/Sagun/test/colored/',batch_size=32,img_size=(256,256))
incep_valid_datagen = InceptionImageGenerator('/content/drive/MyDrive/Major_Project/Image_Dataset/Sagun/val/colored/',batch_size=32,img_size=(256,256))

# %%
sample = incep_train_datagen[0]
sample[0][0].shape
# Out:
# (32, 256, 256, 1)

# %%
sample[0][1].shape
# Out:
# (32, 1000)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 64  640         ['input_2[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 12  73856       ['conv2d[0][0]']
#                                 8)
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 128)  147584      ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 256)  295168      ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 256)  590080      ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 512)  1180160     ['conv2d_4[0][0]']
#
#  input_1 (InputLayer)           [(None, 1000)]       0           []
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  2359808     ['conv2d_5[0][0]']
#
#  repeat_vector (RepeatVector)   (None, 1024, 1000)   0           ['input_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  1179904     ['conv2d_6[0][0]']
#
#  reshape (Reshape)              (None, 32, 32, 1000  0           ['repeat_vector[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 32, 32, 1256  0           ['conv2d_7[0][0]',
#                                 )                                 'reshape[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 256)  321792      ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 128)  295040      ['conv2d_8[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 128)  0           ['conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 64)   73792       ['up_sampling2d[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 64  0          ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 32  18464       ['up_sampling2d_1[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 16  4624        ['conv2d_11[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 2)  290         ['conv2d_12[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 2)  0          ['conv2d_13[0][0]']
#
# ==================================================================================================
# Total params: 6,541,202
# Trainable params: 6,541,202
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from PIL import Image
plot_model(model, 'model_diagram.png')
plt.figure(figsize=(100, 60))
plt.imshow(Image.open('model_diagram.png'))

# %%
tensorboard = TensorBoard(log_dir="/content/drive/MyDrive/Major_Project/Final_models")
checkpoint_filepath = '/content/drive/MyDrive/Major_Project/checkpointFinal_models/r'
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath+'incep_mse_finetune_{epoch:02d}-{loss:.2f}.h5',
    save_freq=203*5, monitor='val_accuracy', mode='max',verbose=1, save_best_only=True)
model.compile(optimizer=tf.keras.optimizers.Adam(0.0001), loss='mse',metrics=['accuracy','RootMeanSquaredError'])
hist = model.fit(incep_train_datagen,validation_data=incep_valid_datagen,callbacks=[model_checkpoint,tensorboard],epochs=200)
# Out:
# Epoch 1/200
# 53/53 [==============================] - 128s 2s/step - loss: 0.0130 - accuracy: 0.5198 - root_mean_squared_error: 0.1139 - val_loss: 0.0116 - val_accuracy: 0.5497 - val_root_mean_squared_error: 0.1076
# Epoch 2/200
# 53/53 [==============================] - 108s 2s/step - loss: 0.0119 - accuracy: 0.5662 - root_mean_squared_error: 0.1089 - val_loss: 0.0112 - val_accuracy: 0.5914 - val_root_mean_squared_error: 0.1060
# Epoch 3/200
# 53/53 [==============================] - 106s 2s/step - loss: 0.0116 - accuracy: 0.5888 - root_mean_squared_error: 0.1076 - val_loss: 0.0109 - val_accuracy: 0.5943 - val_root_mean_squared_error: 0.1046
# Epoch 4/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0112 - accuracy: 0.6135 - root_mean_squared_error: 0.1057 - val_loss: 0.0109 - val_accuracy: 0.6073 - val_root_mean_squared_error: 0.1044
# Epoch 5/200
# 53/53 [==============================] - 102s 2s/step - loss: 0.0110 - accuracy: 0.6082 - root_mean_squared_error: 0.1048 - val_loss: 0.0106 - val_accuracy: 0.6169 - val_root_mean_squared_error: 0.1030
# Epoch 6/200
# 53/53 [==============================] - 104s 2s/step - loss: 0.0107 - accuracy: 0.6201 - root_mean_squared_error: 0.1036 - val_loss: 0.0105 - val_accuracy: 0.6178 - val_root_mean_squared_error: 0.1026
# Epoch 7/200
# 53/53 [==============================] - 105s 2s/step - loss: 0.0105 - accuracy: 0.6281 - root_mean_squared_error: 0.1025 - val_loss: 0.0100 - val_accuracy: 0.6319 - val_root_mean_squared_error: 0.1002
# Epoch 8/200
# 53/53 [==============================] - 104s 2s/step - loss: 0.0105 - accuracy: 0.6295 - root_mean_squared_error: 0.1023 - val_loss: 0.0100 - val_accuracy: 0.6341 - val_root_mean_squared_error: 0.0999
# Epoch 9/200
# 53/53 [==============================] - 104s 2s/step - loss: 0.0104 - accuracy: 0.6331 - root_mean_squared_error: 0.1018 - val_loss: 0.0100 - val_accuracy: 0.6356 - val_root_mean_squared_error: 0.1000
# Epoch 10/200
# 53/53 [==============================] - 103s 2s/step - loss: 0.0101 - accuracy: 0.6393 - root_mean_squared_error: 0.1003 - val_loss: 0.0097 - val_accuracy: 0.6348 - val_root_mean_squared_error: 0.0987
# Epoch 11/200
# 53/53 [==============================] - 104s 2s/step - loss: 0.0100 - accuracy: 0.6386 - root_mean_squared_error: 0.0998 - val_loss: 0.0099 - val_accuracy: 0.6327 - val_root_mean_squared_error: 0.0994
# Epoch 12/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0099 - accuracy: 0.6424 - root_mean_squared_error: 0.0993 - val_loss: 0.0097 - val_accuracy: 0.6277 - val_root_mean_squared_error: 0.0985
# Epoch 13/200
# 53/53 [==============================] - 108s 2s/step - loss: 0.0096 - accuracy: 0.6497 - root_mean_squared_error: 0.0977 - val_loss: 0.0094 - val_accuracy: 0.6472 - val_root_mean_squared_error: 0.0972
# Epoch 14/200
# 53/53 [==============================] - 108s 2s/step - loss: 0.0093 - accuracy: 0.6554 - root_mean_squared_error: 0.0966 - val_loss: 0.0096 - val_accuracy: 0.6507 - val_root_mean_squared_error: 0.0978
# Epoch 15/200
# 53/53 [==============================] - 108s 2s/step - loss: 0.0094 - accuracy: 0.6512 - root_mean_squared_error: 0.0969 - val_loss: 0.0094 - val_accuracy: 0.6436 - val_root_mean_squared_error: 0.0967
# Epoch 16/200
# 53/53 [==============================] - 108s 2s/step - loss: 0.0093 - accuracy: 0.6533 - root_mean_squared_error: 0.0962 - val_loss: 0.0094 - val_accuracy: 0.6417 - val_root_mean_squared_error: 0.0968
# Epoch 17/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0089 - accuracy: 0.6617 - root_mean_squared_error: 0.0946 - val_loss: 0.0098 - val_accuracy: 0.6441 - val_root_mean_squared_error: 0.0988
# Epoch 18/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0088 - accuracy: 0.6671 - root_mean_squared_error: 0.0941 - val_loss: 0.0092 - val_accuracy: 0.6488 - val_root_mean_squared_error: 0.0957
# Epoch 19/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0087 - accuracy: 0.6642 - root_mean_squared_error: 0.0935 - val_loss: 0.0091 - val_accuracy: 0.6553 - val_root_mean_squared_error: 0.0954
# Epoch 20/200
#  7/53 [==>...........................] - ETA: 1:21 - loss: 0.0083 - accuracy: 0.6642 - root_mean_squared_error: 0.0908WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 53/53 [==============================] - 108s 2s/step - loss: 0.0085 - accuracy: 0.6706 - root_mean_squared_error: 0.0920 - val_loss: 0.0092 - val_accuracy: 0.6482 - val_root_mean_squared_error: 0.0958
# Epoch 21/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0084 - accuracy: 0.6726 - root_mean_squared_error: 0.0914 - val_loss: 0.0089 - val_accuracy: 0.6610 - val_root_mean_squared_error: 0.0943
# Epoch 22/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0082 - accuracy: 0.6790 - root_mean_squared_error: 0.0905 - val_loss: 0.0091 - val_accuracy: 0.6614 - val_root_mean_squared_error: 0.0954
# Epoch 23/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0081 - accuracy: 0.6785 - root_mean_squared_error: 0.0900 - val_loss: 0.0088 - val_accuracy: 0.6649 - val_root_mean_squared_error: 0.0936
# Epoch 24/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0078 - accuracy: 0.6835 - root_mean_squared_error: 0.0883 - val_loss: 0.0087 - val_accuracy: 0.6671 - val_root_mean_squared_error: 0.0935
# Epoch 25/200
# 53/53 [==============================] - 106s 2s/step - loss: 0.0077 - accuracy: 0.6872 - root_mean_squared_error: 0.0876 - val_loss: 0.0085 - val_accuracy: 0.6623 - val_root_mean_squared_error: 0.0922
# Epoch 26/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0075 - accuracy: 0.6901 - root_mean_squared_error: 0.0863 - val_loss: 0.0084 - val_accuracy: 0.6779 - val_root_mean_squared_error: 0.0918
# Epoch 27/200
# 53/53 [==============================] - 106s 2s/step - loss: 0.0072 - accuracy: 0.6965 - root_mean_squared_error: 0.0851 - val_loss: 0.0083 - val_accuracy: 0.6787 - val_root_mean_squared_error: 0.0911
# Epoch 28/200
# 53/53 [==============================] - 105s 2s/step - loss: 0.0071 - accuracy: 0.6974 - root_mean_squared_error: 0.0841 - val_loss: 0.0082 - val_accuracy: 0.6726 - val_root_mean_squared_error: 0.0907
# Epoch 29/200
# 53/53 [==============================] - 100s 2s/step - loss: 0.0068 - accuracy: 0.7061 - root_mean_squared_error: 0.0827 - val_loss: 0.0081 - val_accuracy: 0.6837 - val_root_mean_squared_error: 0.0899
# Epoch 30/200
# 53/53 [==============================] - 103s 2s/step - loss: 0.0067 - accuracy: 0.7087 - root_mean_squared_error: 0.0817 - val_loss: 0.0079 - val_accuracy: 0.6831 - val_root_mean_squared_error: 0.0891
# Epoch 31/200
# 53/53 [==============================] - 108s 2s/step - loss: 0.0065 - accuracy: 0.7099 - root_mean_squared_error: 0.0808 - val_loss: 0.0081 - val_accuracy: 0.6880 - val_root_mean_squared_error: 0.0898
# Epoch 32/200
# 53/53 [==============================] - 108s 2s/step - loss: 0.0064 - accuracy: 0.7131 - root_mean_squared_error: 0.0801 - val_loss: 0.0079 - val_accuracy: 0.6907 - val_root_mean_squared_error: 0.0889
# Epoch 33/200
# 53/53 [==============================] - 110s 2s/step - loss: 0.0061 - accuracy: 0.7162 - root_mean_squared_error: 0.0784 - val_loss: 0.0079 - val_accuracy: 0.6878 - val_root_mean_squared_error: 0.0887
# Epoch 34/200
# 53/53 [==============================] - 108s 2s/step - loss: 0.0059 - accuracy: 0.7224 - root_mean_squared_error: 0.0768 - val_loss: 0.0079 - val_accuracy: 0.6926 - val_root_mean_squared_error: 0.0888
# Epoch 35/200
# 53/53 [==============================] - 109s 2s/step - loss: 0.0058 - accuracy: 0.7218 - root_mean_squared_error: 0.0762 - val_loss: 0.0080 - val_accuracy: 0.6917 - val_root_mean_squared_error: 0.0892
# Epoch 36/200
# 53/53 [==============================] - 110s 2s/step - loss: 0.0056 - accuracy: 0.7253 - root_mean_squared_error: 0.0751 - val_loss: 0.0078 - val_accuracy: 0.6993 - val_root_mean_squared_error: 0.0885
# Epoch 37/200
# 53/53 [==============================] - 108s 2s/step - loss: 0.0057 - accuracy: 0.7284 - root_mean_squared_error: 0.0756 - val_loss: 0.0075 - val_accuracy: 0.7008 - val_root_mean_squared_error: 0.0864
# Epoch 38/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0053 - accuracy: 0.7356 - root_mean_squared_error: 0.0727 - val_loss: 0.0073 - val_accuracy: 0.7042 - val_root_mean_squared_error: 0.0857
# Epoch 39/200
# 15/53 [=======>......................] - ETA: 1:00 - loss: 0.0050 - accuracy: 0.7382 - root_mean_squared_error: 0.0707WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 53/53 [==============================] - 104s 2s/step - loss: 0.0051 - accuracy: 0.7365 - root_mean_squared_error: 0.0713 - val_loss: 0.0076 - val_accuracy: 0.7064 - val_root_mean_squared_error: 0.0869
# Epoch 40/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0048 - accuracy: 0.7428 - root_mean_squared_error: 0.0695 - val_loss: 0.0072 - val_accuracy: 0.7071 - val_root_mean_squared_error: 0.0848
# Epoch 41/200
# 53/53 [==============================] - 106s 2s/step - loss: 0.0047 - accuracy: 0.7486 - root_mean_squared_error: 0.0682 - val_loss: 0.0072 - val_accuracy: 0.7104 - val_root_mean_squared_error: 0.0846
# Epoch 42/200
# 53/53 [==============================] - 105s 2s/step - loss: 0.0045 - accuracy: 0.7523 - root_mean_squared_error: 0.0674 - val_loss: 0.0072 - val_accuracy: 0.7068 - val_root_mean_squared_error: 0.0846
# Epoch 43/200
# 53/53 [==============================] - 111s 2s/step - loss: 0.0044 - accuracy: 0.7509 - root_mean_squared_error: 0.0664 - val_loss: 0.0071 - val_accuracy: 0.6977 - val_root_mean_squared_error: 0.0844
# Epoch 44/200
# 53/53 [==============================] - 105s 2s/step - loss: 0.0043 - accuracy: 0.7521 - root_mean_squared_error: 0.0658 - val_loss: 0.0070 - val_accuracy: 0.7116 - val_root_mean_squared_error: 0.0835
# Epoch 45/200
# 53/53 [==============================] - 105s 2s/step - loss: 0.0040 - accuracy: 0.7609 - root_mean_squared_error: 0.0636 - val_loss: 0.0069 - val_accuracy: 0.7107 - val_root_mean_squared_error: 0.0830
# Epoch 46/200
# 53/53 [==============================] - 105s 2s/step - loss: 0.0041 - accuracy: 0.7631 - root_mean_squared_error: 0.0643 - val_loss: 0.0073 - val_accuracy: 0.6972 - val_root_mean_squared_error: 0.0856
# Epoch 47/200
# 53/53 [==============================] - 105s 2s/step - loss: 0.0039 - accuracy: 0.7670 - root_mean_squared_error: 0.0628 - val_loss: 0.0069 - val_accuracy: 0.7205 - val_root_mean_squared_error: 0.0828
# Epoch 48/200
# 53/53 [==============================] - 110s 2s/step - loss: 0.0037 - accuracy: 0.7748 - root_mean_squared_error: 0.0607 - val_loss: 0.0067 - val_accuracy: 0.7121 - val_root_mean_squared_error: 0.0821
# Epoch 49/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0036 - accuracy: 0.7764 - root_mean_squared_error: 0.0598 - val_loss: 0.0067 - val_accuracy: 0.7180 - val_root_mean_squared_error: 0.0817
# Epoch 50/200
# 53/53 [==============================] - 104s 2s/step - loss: 0.0035 - accuracy: 0.7787 - root_mean_squared_error: 0.0591 - val_loss: 0.0070 - val_accuracy: 0.7185 - val_root_mean_squared_error: 0.0838
# Epoch 51/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0036 - accuracy: 0.7772 - root_mean_squared_error: 0.0598 - val_loss: 0.0069 - val_accuracy: 0.7284 - val_root_mean_squared_error: 0.0831
# Epoch 52/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0036 - accuracy: 0.7815 - root_mean_squared_error: 0.0599 - val_loss: 0.0066 - val_accuracy: 0.7256 - val_root_mean_squared_error: 0.0812
# Epoch 53/200
# 53/53 [==============================] - 108s 2s/step - loss: 0.0033 - accuracy: 0.7865 - root_mean_squared_error: 0.0576 - val_loss: 0.0066 - val_accuracy: 0.7271 - val_root_mean_squared_error: 0.0813
# Epoch 54/200
# 53/53 [==============================] - 106s 2s/step - loss: 0.0032 - accuracy: 0.7876 - root_mean_squared_error: 0.0568 - val_loss: 0.0065 - val_accuracy: 0.7236 - val_root_mean_squared_error: 0.0808
# Epoch 55/200
# 53/53 [==============================] - 106s 2s/step - loss: 0.0032 - accuracy: 0.7907 - root_mean_squared_error: 0.0563 - val_loss: 0.0066 - val_accuracy: 0.7327 - val_root_mean_squared_error: 0.0815
# Epoch 56/200
# 53/53 [==============================] - 106s 2s/step - loss: 0.0031 - accuracy: 0.7907 - root_mean_squared_error: 0.0557 - val_loss: 0.0066 - val_accuracy: 0.7169 - val_root_mean_squared_error: 0.0810
# Epoch 57/200
# 53/53 [==============================] - 108s 2s/step - loss: 0.0032 - accuracy: 0.7894 - root_mean_squared_error: 0.0568 - val_loss: 0.0065 - val_accuracy: 0.7256 - val_root_mean_squared_error: 0.0807
# Epoch 58/200
# 23/53 [============>.................] - ETA: 50s - loss: 0.0031 - accuracy: 0.7912 - root_mean_squared_error: 0.0554WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 53/53 [==============================] - 107s 2s/step - loss: 0.0031 - accuracy: 0.7947 - root_mean_squared_error: 0.0553 - val_loss: 0.0063 - val_accuracy: 0.7358 - val_root_mean_squared_error: 0.0796
# Epoch 59/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0030 - accuracy: 0.7975 - root_mean_squared_error: 0.0546 - val_loss: 0.0064 - val_accuracy: 0.7362 - val_root_mean_squared_error: 0.0802
# Epoch 60/200
# 53/53 [==============================] - 100s 2s/step - loss: 0.0029 - accuracy: 0.8043 - root_mean_squared_error: 0.0534 - val_loss: 0.0064 - val_accuracy: 0.7352 - val_root_mean_squared_error: 0.0802
# Epoch 61/200
# 53/53 [==============================] - 100s 2s/step - loss: 0.0028 - accuracy: 0.8059 - root_mean_squared_error: 0.0533 - val_loss: 0.0063 - val_accuracy: 0.7412 - val_root_mean_squared_error: 0.0791
# Epoch 62/200
# 53/53 [==============================] - 99s 2s/step - loss: 0.0028 - accuracy: 0.8067 - root_mean_squared_error: 0.0525 - val_loss: 0.0064 - val_accuracy: 0.7397 - val_root_mean_squared_error: 0.0798
# Epoch 63/200
# 53/53 [==============================] - 100s 2s/step - loss: 0.0028 - accuracy: 0.8072 - root_mean_squared_error: 0.0527 - val_loss: 0.0064 - val_accuracy: 0.7342 - val_root_mean_squared_error: 0.0799
# Epoch 64/200
# 53/53 [==============================] - 100s 2s/step - loss: 0.0027 - accuracy: 0.8056 - root_mean_squared_error: 0.0523 - val_loss: 0.0063 - val_accuracy: 0.7248 - val_root_mean_squared_error: 0.0796
# Epoch 65/200
# 53/53 [==============================] - 105s 2s/step - loss: 0.0026 - accuracy: 0.8111 - root_mean_squared_error: 0.0512 - val_loss: 0.0063 - val_accuracy: 0.7456 - val_root_mean_squared_error: 0.0792
# Epoch 66/200
# 53/53 [==============================] - 107s 2s/step - loss: 0.0025 - accuracy: 0.8152 - root_mean_squared_error: 0.0504 - val_loss: 0.0062 - val_accuracy: 0.7453 - val_root_mean_squared_error: 0.0786
# Epoch 67/200
# 53/53 [==============================] - 104s 2s/step - loss: 0.0025 - accuracy: 0.8144 - root_mean_squared_error: 0.0504 - val_loss: 0.0062 - val_accuracy: 0.7424 - val_root_mean_squared_error: 0.0785
# Epoch 68/200
# 53/53 [==============================] - 104s 2s/step - loss: 0.0025 - accuracy: 0.8172 - root_mean_squared_error: 0.0499 - val_loss: 0.0062 - val_accuracy: 0.7456 - val_root_mean_squared_error: 0.0789
# Epoch 69/200
# 53/53 [==============================] - 102s 2s/step - loss: 0.0025 - accuracy: 0.8181 - root_mean_squared_error: 0.0501 - val_loss: 0.0066 - val_accuracy: 0.7437 - val_root_mean_squared_error: 0.0814
# Epoch 70/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0026 - accuracy: 0.8134 - root_mean_squared_error: 0.0514 - val_loss: 0.0062 - val_accuracy: 0.7456 - val_root_mean_squared_error: 0.0785
# Epoch 71/200
# 53/53 [==============================] - 102s 2s/step - loss: 0.0026 - accuracy: 0.8168 - root_mean_squared_error: 0.0510 - val_loss: 0.0064 - val_accuracy: 0.7473 - val_root_mean_squared_error: 0.0798
# Epoch 72/200
# 53/53 [==============================] - 103s 2s/step - loss: 0.0024 - accuracy: 0.8232 - root_mean_squared_error: 0.0494 - val_loss: 0.0063 - val_accuracy: 0.7486 - val_root_mean_squared_error: 0.0791
# Epoch 73/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0023 - accuracy: 0.8256 - root_mean_squared_error: 0.0483 - val_loss: 0.0061 - val_accuracy: 0.7475 - val_root_mean_squared_error: 0.0782
# Epoch 74/200
# 53/53 [==============================] - 102s 2s/step - loss: 0.0024 - accuracy: 0.8172 - root_mean_squared_error: 0.0488 - val_loss: 0.0060 - val_accuracy: 0.7508 - val_root_mean_squared_error: 0.0777
# Epoch 75/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0025 - accuracy: 0.8212 - root_mean_squared_error: 0.0496 - val_loss: 0.0062 - val_accuracy: 0.7487 - val_root_mean_squared_error: 0.0785
# Epoch 76/200
# 53/53 [==============================] - 102s 2s/step - loss: 0.0024 - accuracy: 0.8255 - root_mean_squared_error: 0.0489 - val_loss: 0.0061 - val_accuracy: 0.7461 - val_root_mean_squared_error: 0.0782
# Epoch 77/200
# 31/53 [================>.............] - ETA: 36s - loss: 0.0023 - accuracy: 0.8307 - root_mean_squared_error: 0.0480WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 53/53 [==============================] - 101s 2s/step - loss: 0.0023 - accuracy: 0.8295 - root_mean_squared_error: 0.0483 - val_loss: 0.0061 - val_accuracy: 0.7475 - val_root_mean_squared_error: 0.0779
# Epoch 78/200
# 53/53 [==============================] - 100s 2s/step - loss: 0.0023 - accuracy: 0.8293 - root_mean_squared_error: 0.0476 - val_loss: 0.0060 - val_accuracy: 0.7545 - val_root_mean_squared_error: 0.0773
# Epoch 79/200
# 53/53 [==============================] - 99s 2s/step - loss: 0.0022 - accuracy: 0.8289 - root_mean_squared_error: 0.0474 - val_loss: 0.0061 - val_accuracy: 0.7499 - val_root_mean_squared_error: 0.0782
# Epoch 80/200
# 53/53 [==============================] - 99s 2s/step - loss: 0.0022 - accuracy: 0.8327 - root_mean_squared_error: 0.0468 - val_loss: 0.0059 - val_accuracy: 0.7555 - val_root_mean_squared_error: 0.0771
# Epoch 81/200
# 53/53 [==============================] - 100s 2s/step - loss: 0.0022 - accuracy: 0.8334 - root_mean_squared_error: 0.0470 - val_loss: 0.0061 - val_accuracy: 0.7504 - val_root_mean_squared_error: 0.0780
# Epoch 82/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0021 - accuracy: 0.8360 - root_mean_squared_error: 0.0462 - val_loss: 0.0059 - val_accuracy: 0.7558 - val_root_mean_squared_error: 0.0771
# Epoch 83/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0022 - accuracy: 0.8328 - root_mean_squared_error: 0.0466 - val_loss: 0.0059 - val_accuracy: 0.7546 - val_root_mean_squared_error: 0.0770
# Epoch 84/200
# 53/53 [==============================] - 102s 2s/step - loss: 0.0022 - accuracy: 0.8315 - root_mean_squared_error: 0.0466 - val_loss: 0.0060 - val_accuracy: 0.7571 - val_root_mean_squared_error: 0.0777
# Epoch 85/200
# 53/53 [==============================] - 102s 2s/step - loss: 0.0024 - accuracy: 0.8185 - root_mean_squared_error: 0.0486 - val_loss: 0.0063 - val_accuracy: 0.7313 - val_root_mean_squared_error: 0.0796
# Epoch 86/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0024 - accuracy: 0.8174 - root_mean_squared_error: 0.0494 - val_loss: 0.0062 - val_accuracy: 0.7478 - val_root_mean_squared_error: 0.0790
# Epoch 87/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0023 - accuracy: 0.8321 - root_mean_squared_error: 0.0475 - val_loss: 0.0061 - val_accuracy: 0.7518 - val_root_mean_squared_error: 0.0779
# Epoch 88/200
# 53/53 [==============================] - 102s 2s/step - loss: 0.0022 - accuracy: 0.8332 - root_mean_squared_error: 0.0468 - val_loss: 0.0059 - val_accuracy: 0.7505 - val_root_mean_squared_error: 0.0771
# Epoch 89/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0021 - accuracy: 0.8373 - root_mean_squared_error: 0.0459 - val_loss: 0.0060 - val_accuracy: 0.7568 - val_root_mean_squared_error: 0.0777
# Epoch 90/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0021 - accuracy: 0.8389 - root_mean_squared_error: 0.0459 - val_loss: 0.0059 - val_accuracy: 0.7592 - val_root_mean_squared_error: 0.0769
# Epoch 91/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0020 - accuracy: 0.8398 - root_mean_squared_error: 0.0452 - val_loss: 0.0059 - val_accuracy: 0.7549 - val_root_mean_squared_error: 0.0767
# Epoch 92/200
# 53/53 [==============================] - 100s 2s/step - loss: 0.0020 - accuracy: 0.8413 - root_mean_squared_error: 0.0446 - val_loss: 0.0059 - val_accuracy: 0.7522 - val_root_mean_squared_error: 0.0769
# Epoch 93/200
# 53/53 [==============================] - 99s 2s/step - loss: 0.0019 - accuracy: 0.8438 - root_mean_squared_error: 0.0440 - val_loss: 0.0059 - val_accuracy: 0.7577 - val_root_mean_squared_error: 0.0766
# Epoch 94/200
# 53/53 [==============================] - 99s 2s/step - loss: 0.0019 - accuracy: 0.8464 - root_mean_squared_error: 0.0436 - val_loss: 0.0058 - val_accuracy: 0.7594 - val_root_mean_squared_error: 0.0762
# Epoch 95/200
# 53/53 [==============================] - 98s 2s/step - loss: 0.0019 - accuracy: 0.8461 - root_mean_squared_error: 0.0433 - val_loss: 0.0059 - val_accuracy: 0.7595 - val_root_mean_squared_error: 0.0766
# Epoch 96/200
# 39/53 [=====================>........] - ETA: 22s - loss: 0.0019 - accuracy: 0.8500 - root_mean_squared_error: 0.0433WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 53/53 [==============================] - 98s 2s/step - loss: 0.0019 - accuracy: 0.8475 - root_mean_squared_error: 0.0433 - val_loss: 0.0058 - val_accuracy: 0.7618 - val_root_mean_squared_error: 0.0763
# Epoch 97/200
# 53/53 [==============================] - 98s 2s/step - loss: 0.0019 - accuracy: 0.8448 - root_mean_squared_error: 0.0436 - val_loss: 0.0058 - val_accuracy: 0.7628 - val_root_mean_squared_error: 0.0764
# Epoch 98/200
# 53/53 [==============================] - 98s 2s/step - loss: 0.0020 - accuracy: 0.8434 - root_mean_squared_error: 0.0442 - val_loss: 0.0061 - val_accuracy: 0.7538 - val_root_mean_squared_error: 0.0782
# Epoch 99/200
# 53/53 [==============================] - 98s 2s/step - loss: 0.0021 - accuracy: 0.8326 - root_mean_squared_error: 0.0454 - val_loss: 0.0065 - val_accuracy: 0.7186 - val_root_mean_squared_error: 0.0807
# Epoch 100/200
# 53/53 [==============================] - 99s 2s/step - loss: 0.0021 - accuracy: 0.8307 - root_mean_squared_error: 0.0463 - val_loss: 0.0059 - val_accuracy: 0.7534 - val_root_mean_squared_error: 0.0769
# Epoch 101/200
# 53/53 [==============================] - 99s 2s/step - loss: 0.0020 - accuracy: 0.8392 - root_mean_squared_error: 0.0449 - val_loss: 0.0059 - val_accuracy: 0.7590 - val_root_mean_squared_error: 0.0766
# Epoch 102/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0020 - accuracy: 0.8416 - root_mean_squared_error: 0.0446 - val_loss: 0.0059 - val_accuracy: 0.7574 - val_root_mean_squared_error: 0.0765
# Epoch 103/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0019 - accuracy: 0.8428 - root_mean_squared_error: 0.0441 - val_loss: 0.0058 - val_accuracy: 0.7635 - val_root_mean_squared_error: 0.0762
# Epoch 104/200
# 53/53 [==============================] - 101s 2s/step - loss: 0.0019 - accuracy: 0.8456 - root_mean_squared_error: 0.0436 - val_loss: 0.0059 - val_accuracy: 0.7641 - val_root_mean_squared_error: 0.0765
# Epoch 105/200
# 53/53 [==============================] - 100s 2s/step - loss: 0.0019 - accuracy: 0.8486 - root_mean_squared_error: 0.0433 - val_loss: 0.0058 - val_accuracy: 0.7602 - val_root_mean_squared_error: 0.0762
# Epoch 106/200
# 53/53 [==============================] - 99s 2s/step - loss: 0.0019 - accuracy: 0.8476 - root_mean_squared_error: 0.0435 - val_loss: 0.0060 - val_accuracy: 0.7634 - val_root_mean_squared_error: 0.0772
# Epoch 107/200
# 53/53 [==============================] - 100s 2s/step - loss: 0.0020 - accuracy: 0.8426 - root_mean_squared_error: 0.0452 - val_loss: 0.0058 - val_accuracy: 0.7585 - val_root_mean_squared_error: 0.0762
# Epoch 108/200
# 53/53 [==============================] - 99s 2s/step - loss: 0.0020 - accuracy: 0.8429 - root_mean_squared_error: 0.0448 - val_loss: 0.0058 - val_accuracy: 0.7627 - val_root_mean_squared_error: 0.0764
# Epoch 109/200
# 53/53 [==============================] - 99s 2s/step - loss: 0.0020 - accuracy: 0.8410 - root_mean_squared_error: 0.0449 - val_loss: 0.0059 - val_accuracy: 0.7601 - val_root_mean_squared_error: 0.0769
# Epoch 110/200
# 53/53 [==============================] - 98s 2s/step - loss: 0.0019 - accuracy: 0.8447 - root_mean_squared_error: 0.0441 - val_loss: 0.0057 - val_accuracy: 0.7613 - val_root_mean_squared_error: 0.0757
# Epoch 111/200
# 53/53 [==============================] - 99s 2s/step - loss: 0.0021 - accuracy: 0.8410 - root_mean_squared_error: 0.0463 - val_loss: 0.0059 - val_accuracy: 0.7573 - val_root_mean_squared_error: 0.0768
# Epoch 112/200
# 53/53 [==============================] - 99s 2s/step - loss: 0.0021 - accuracy: 0.8385 - root_mean_squared_error: 0.0460 - val_loss: 0.0058 - val_accuracy: 0.7589 - val_root_mean_squared_error: 0.0763
# Epoch 113/200
# 53/53 [==============================] - 98s 2s/step - loss: 0.0019 - accuracy: 0.8465 - root_mean_squared_error: 0.0436 - val_loss: 0.0059 - val_accuracy: 0.7598 - val_root_mean_squared_error: 0.0767
# Epoch 114/200
# 53/53 [==============================] - 98s 2s/step - loss: 0.0019 - accuracy: 0.8460 - root_mean_squared_error: 0.0430 - val_loss: 0.0058 - val_accuracy: 0.7647 - val_root_mean_squared_error: 0.0759
# Epoch 115/200
# 47/53 [=========================>....] - ETA: 9s - loss: 0.0018 - accuracy: 0.8518 - root_mean_squared_error: 0.0420 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 53/53 [==============================] - 98s 2s/step - loss: 0.0017 - accuracy: 0.8526 - root_mean_squared_error: 0.0418 - val_loss: 0.0056 - val_accuracy: 0.7663 - val_root_mean_squared_error: 0.0751
# Epoch 116/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.8561 - root_mean_squared_error: 0.0410

# %%
print(hist.history.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-67c1d0aca0d1> in <module>()
# ----> 1 print(hist.history.keys())
#
# NameError: name 'hist' is not defined

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# summarize history for loss
plt.plot(hist.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
model.save("/content/drive/MyDrive/Major_Project/save_model/Final_modelsefficientnetB0.h5")

# %%
# loading library
import pickle
loc='/content/drive/MyDrive/Major_Project/picklefile/'
# create an iterator object with write permission - model.pkl
with open(loc+'Final_modelsefficientnetB0.pkl', 'wb') as files:
    pickle.dump(hist.history, files)

# %%
# load saved model
with open('/content/drive/MyDrive/Major_Project/picklefile/Final_modelsefficientnetB0.pkl' , 'rb') as f:
    lr = pickle.load(f)

# %%
model.load_weights("/content/drive/MyDrive/Major_Project/save_model/Final_modelsefficientnetB0.h5")

# %%
from glob import glob
import numpy as np
import pickle as pickle
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style(style='white')
#Give your model directory here
all_pickles = sorted(glob('/content/drive/MyDrive/Major_Project/picklefile/*.pkl'))
model_names = [item[8:-7] for item in all_pickles]
valid_loss = [pickle.load( open( i, "rb" ) )['val_loss'] for i in all_pickles]
train_loss = [pickle.load( open( i, "rb" ) )['loss'] for i in all_pickles]
train_accuracy=[pickle.load( open( i, "rb" ) )['accuracy'] for i in all_pickles]
valid_accuracy=[pickle.load( open( i, "rb" ) )['accuracy'] for i in all_pickles]
train_rmse=[pickle.load( open( i, "rb" ) )['root_mean_squared_error'] for i in all_pickles]
valid_rmse=[pickle.load( open( i, "rb" ) )['val_root_mean_squared_error'] for i in all_pickles]

num_epochs = [len(valid_loss[i]) for i in range(len(valid_loss))]

#************************************** Training & Valadation Loss Plot*******************************#
fig = plt.figure(figsize=(16,5))
ax1 = fig.add_subplot(121)
for i in range(len(all_pickles)):
    ax1.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            train_loss[i], label=model_names[i])
ax1.legend()  
ax1.set_xlim([1, max(num_epochs,default=0)])
plt.xlabel('Epoch')
plt.ylabel('Training Loss')

ax2 = fig.add_subplot(122)
for i in range(len(all_pickles)):
    ax2.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            valid_loss[i], label=model_names[i])
ax2.legend()  
ax2.set_xlim([1, max(num_epochs,default=0)])
plt.xlabel('Epoch')
plt.ylabel('Validation_loss')
plt.show()

#************************************** Training & Valadation accuracy Plot*******************************#
fig = plt.figure(figsize=(16,5))
ax1 = fig.add_subplot(121)
for i in range(len(all_pickles)):
    ax1.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            train_accuracy[i], label=model_names[i])
ax1.legend()  
ax1.set_xlim([1, max(num_epochs,default=0)])
plt.xlabel('Epoch')
plt.ylabel('Training Accuracy')

ax2 = fig.add_subplot(122)
for i in range(len(all_pickles)):
    ax2.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            valid_accuracy[i], label=model_names[i])
ax2.legend()  
ax2.set_xlim([1, max(num_epochs,default=0)])
plt.xlabel('Epoch')
plt.ylabel('Validation_accuracy')
plt.show()


#************************************** Training & Valadation RMSE Plot*******************************#

fig = plt.figure(figsize=(16,5))
ax1 = fig.add_subplot(121)
for i in range(len(all_pickles)):
    ax1.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            train_rmse[i], label=model_names[i])
ax1.legend()  
ax1.set_xlim([1, max(num_epochs,default=0)])
plt.xlabel('Epoch')
plt.ylabel('Train_root_mean_squared_error')

ax2 = fig.add_subplot(122)
for i in range(len(all_pickles)):
    ax2.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
            valid_rmse[i], label=model_names[i])
ax2.legend()  
ax2.set_xlim([1, max(num_epochs,default=0)])
plt.xlabel('Epoch')
plt.ylabel('Validation_root_mean_squared_error')
plt.show()

# %%
def to_rgb(gray, ab):
    '''rgb image from grayscale and ab channels'''
    ab = ab*128
    lab_img = np.concatenate((gray,ab),axis=2)
    rgb_img = lab2rgb(lab_img)
    # rgb_img = (rgb_img*255).astype('uint8')
    return rgb_img

# %%
sample = incep_train_datagen[0]      #next(image_a_b_gen(10))
#print(.shape)
prediction = model.predict([sample[0][0],sample[0][1]])
prediction *= 128
op = np.zeros((32,256, 256, 3))
op[:,:,:,0] = sample[0][0][:,:,:,0]
op[:,:,:,1:] = prediction

# %%
original = to_rgb(sample[0][0][4], sample[1][4])

plt.figure(figsize=(15,10))
plt.subplot(221)
plt.imshow(lab2rgb(op[4]))
plt.title('Predicted')
plt.subplot(222)
plt.imshow(original)
plt.title('Actual')

# %%
# Test images
test_images = []
for filename in os.listdir('/content/drive/MyDrive/Major_Project/Image_Dataset/Sagun/b&w/'):
    test_images.append(img_to_array(load_img('/content/drive/MyDrive/Major_Project/Image_Dataset/Sagun/b&w/'+filename,target_size=(256,256))))
test_images = np.array(test_images, dtype=float)
Xtest = rgb2lab(1.0/255*test_images)[:,:,:,0]
Xtest = Xtest.reshape(Xtest.shape+(1,))
Ytest = rgb2lab(1.0/255*test_images)[:,:,:,1:]
Ytest = Ytest / 128
Xtest_embed = 1.0/255*test_images
Xtest_embed = gray2rgb(rgb2gray(Xtest_embed))
Xtest_embed = create_inception_embedding(Xtest_embed)

# print(model.evaluate(Xtest, Ytest, batch_size=batch_size))
outputs = model.predict([Xtest,Xtest_embed])

predicted = []
actual = []
for i in range(len(Xtest)):
    predicted.append(to_rgb(Xtest[i],outputs[i]))
    actual.append(to_rgb(Xtest[i],Ytest[i]))

# %%
# Plot actual and predicted test images
fig, ax = plt.subplots(20, 2, figsize=(16,100))
row = 0
for img in test_images[60:80]:
    ax[row,0].imshow(img/255.0)
    row +=1

row = 0
for img in predicted[60:80]:
	ax[row,1].imshow(img)
	row +=1
